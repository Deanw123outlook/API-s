# %% [markdown]
# # Python Request Library Exception Testing
#
# GOALS
# - Build a model that will test an API's request response time using Python Requests library elapsed time property.
# - We will play around with tiemout parameters and other to test our model expection handling and error raising is succesful.
#
# OBJECTIVES
# - Use a pubic testing endpoint (for testing/data privacy purposes)
# - Code this model using Python Requests linbrary
# - Run x amount of tests (this will depend on functionality etc.)
# - Implement more than one set of values into the Model for testing our Timeout paramters
# - Extract the elapsed time disussed below form our Model (requests elapsed time property)
# - Test exception error handling by changing model input values
# - Input this into pandas dataframe and visually analyse our findings
#
# Useful:
#
# If a client/customer advises they are having issues with an API timing out(potentially at certain times etc.). Minimally the client may request the best timeout thresholds/paramters to succesfully hit the server and perform their required functionality. This in alot of cases will depend on other variables dependent on business needs such as traffic hitting server etc. This script will give a base level of testing.
#
# The following script will build a Model that will help build/gauge the best timeout parameter's for an endpoint based on tesing data. Please see details further below.
#
# #### Import Requried Libraries

# %%
import numpy as np
import pandas as pd

import json # Python built-in package json for encoding and decoding JSON data.
import requests # library for working with HTTP requests in Python

from requests.exceptions import Timeout
from requests.adapters import HTTPAdapter
from requests.exceptions import ConnectionError

import seaborn as sns
import matplotlib.pyplot as plt

from datetime import datetime
import time

# %% [markdown]
# Next, we will discuss some key concepts when using Python's request library.
#
# #### API Performance Analysis
# - Requests Elapsed Time Proprty
#
# The response object returned by post|get requests has a property called elapsed, which provides the time delta between when the request was sent and when the response was received. We can apply total_seconds() method to return this time in seconds. This is useful for testing threshold for our timeout parameter.
#
# - SESSIONS
#
# Sessions object from the Request library enables us to control how requests are being made or to improve the performance of your requests, you may need to use a Session instance directly. Sessions are used to persist parameters across requests. The primary performance optimization of sessions comes in the form of persistent connections. When your app makes a connection to a server using a Session, it keeps that connection around in a connection pool. When your app wants to connect to the same server again, it will reuse a connection from the pool rather than establishing a new one.
#
# - Max Retries
#
# When a request fails, you may want your application to retry the same request. However, requests will not do this for you by default. To apply this functionality, you need to implement a custom Transport Adapter.
#
# Transport Adapters let you define a set of configurations per service you’re interacting with.
#
# - Timeouts
#
# When you make an inline request to an external service, your system will need to wait upon the response before moving on. If your application waits too long for that response, requests to your service could back up, your user experience could suffer, or your background jobs could hang.
#
# By default, requests will wait indefinitely on the response, so you should almost always specify a timeout duration to prevent these things from happening. To set the request’s timeout, use the timeout parameter. timeout can be an integer or float representing the number of seconds to wait on a response before timing out.
#
# NOTE
#
# You can also pass a tuple to timeout with the first element being a connect timeout (the time it allows for the client to establish a connection to the server), and the second being a read timeout (the time it will wait on a response once your client has established a connection)

# %% [markdown]
# #### Model Settings
# - Pre-define values for running in our model (timeout threshold)
# - Create empty lists that will be used to extract specific data from our model
# - Implement a counter variable that will be incremented when our model is running. This will enable us to control testing ie. STOPS the model one a threshold has been reached
# - Loop using the range function (the no. of tests we want to run within each test set)

# %%
# Model Timeout Paramter values
t1 = [0.1,0.2,'Label-Test-1'] # list data structure (ordered)
t2 = [0.4,0.6,'Label-Test-2']
t3 = [0.5,0.8,'Label-Test-3']
dict = {'test_1':t1,'test_2':t2,'test_3':t3} # add list data to dictionary

# Generate list data 1 - x for each individual test 
tests=[] # empty list
request_times = [] # UTC request time (note list data structure to maintain order of our data)
elapsed_times = [] # server response time
category = []

counter = 0 # Emply counter variable which will act as our model test threhold value ie. when the model will stop running

# loop that will build test range
for i in range(1,300,1): # range(start,stop.step)
    tests.append(i) # append (add) items to list

# %% [markdown]
# ### Model
# Build out our model and run our code to extract the required informatiom for evaluation/analysis
#
# We want to test Python Request Library Exception | error handling in below model. This will enable us to determine the models success rate.
#
# exception requests.ConnectTimeout
# - The request timed out while trying to connect to the remote server. Requests that produce this error are safte to retry.
#
# exception requests.ReadTimeout
# - The server did not send any data in the allocated amount of time
#
# exception requests.Timeout
# - The request timed out. Catching this error will catch both the above ConnectTimeout and readTimeout erros.

# %%
for key,value in dict.items(): # TEST-SET (3)
    print("-------------------------------------------------------------------------------------------------------------------")
    print("-------------------------------------------------------------------------------------------------------------------")
    print("TEST-SET : ", key)
    #
    url = "https://api.coindesk.com/v1/bpi/currentprice.json"
    set_adapter = HTTPAdapter(max_retries = 3) # Build Transport Adapter, input max_retries parameter, and mount it to an existing Session:
    time = (value[0],value[1]) # connection timeout (connect,read) seconds
    
    #
    for test in tests:
        if counter < len(tests):
            counter += 1
            print("Test :",counter)
            print("Timeout-Paramter-Values : ", time)
            
            #
            with requests.Session() as session:
                session.mount(url, set_adapter)
                try:
                    #
                    response = session.get(url, timeout=time)
                    dt_request = datetime.now() # Getting the current date and time request executed/processes (time will be close to time server was hit for request)
                    request_times.append(dt_request)
                    timestamp = datetime.timestamp(dt_request) # Getting the timestamp (time will be close to time server was hit for request)
                    
                    #
                    response.raise_for_status() # check if succesfull repsonse code
                    print("Request-Status-Code : {}".format(response.raise_for_status)) # get request status code
                    print("Server Request Date | Time (UTC) : ", dt_request)
                    
                    # label
                    category.append(value[2])
                    print(value[2])
                    
                    #
                    print()
                    print("Requests-Proporty-Server-Repsonse-Time-Seconds",response.elapsed.total_seconds()) # requests property elapsed returns delta between request sent and response receieved
                    time = response.elapsed.total_seconds()
                    elapsed_times.append(time)
                    print()
                    
                    
                # requests Timeout(connect,read) error handling
                except requests.exceptions.ConnectTimeout as error: # request timed out while trying to connect to the remote server.
                    print("Connect-Timeout-Error")
                    raise SystemExit(error)
                except requests.exceptions.ReadTimeout as error:
                    print("Read-Timeout-Error")
                    raise SystemExit(error)
                
                # requests Connection error handling
                except requests.exceptions.ConnectionError as error:
                    print("Connetion Error Raised")
                    raise SystemExit(error)
                
                # requests HTTP status error handling
                except requests.exceptions.HTTPError as error:
                    print("HTTP Error Raised")
                    raise SystemExit(error)
                    
        # stop/exit model
        if counter >= len(tests):
            counter = 0

# Create DataFrame using dictionariy data sturcutre and dataframe method
threshold = pd.DataFrame ({'Request Time UTC':request_times,'Server Request Response Time Seconds':elapsed_times,'Test-Label':category})
threshold.head()
# Out:
# -------------------------------------------------------------------------------------------------------------------
# -------------------------------------------------------------------------------------------------------------------
# TEST-SET :  test_1
# Test : 1
# Timeout-Paramter-Values :  (0.1, 0.2)
# Request-Status-Code : <bound method Response.raise_for_status of <Response [200]>>
# Server Request Date | Time (UTC) :  2023-12-27 15:14:32.948914
# Label-Test-1
#
# Requests-Proporty-Server-Repsonse-Time-Seconds 0.162307
#
# Test : 2
# Timeout-Paramter-Values :  0.162307
# Request-Status-Code : <bound method Response.raise_for_status of <Response [200]>>
# Server Request Date | Time (UTC) :  2023-12-27 15:14:33.018725
# Label-Test-1
#
# Requests-Proporty-Server-Repsonse-Time-Seconds 0.0676
#
# Test : 3
# Timeout-Paramter-Values :  0.0676
# Request-Status-Code : <bound method Response.raise_for_status of <Response [200]>>
# Server Request Date | Time (UTC) :  2023-12-27 15:14:33.088540
# Label-Test-1
#
# Requests-Proporty-Server-Repsonse-Time-Seconds 0.065785
#
# Test : 4
# Timeout-Paramter-Values :  0.065785
# Request-Status-Code : <bound method Response.raise_for_status of <Response [200]>>
# Server Request Date | Time (UTC) :  2023-12-27 15:14:33.149377
# Label-Test-1
#
# Requests-Proporty-Server-Repsonse-Time-Seconds 0.05775
#
# Test : 5
# Timeout-Paramter-Values :  0.05775
# Request-Status-Code : <bound method Response.raise_for_status of <Response [200]>>
# Server Request Date | Time (UTC) :  2023-12-27 15:14:33.220187
# Label-Test-1
#
# Requests-Proporty-Server-Repsonse-Time-Seconds 0.067119
#
# Test : 6
# Timeout-Paramter-Values :  0.067119
# Request-Status-Code : <bound method Response.raise_for_status of <Response [200]>>
# Server Request Date | Time (UTC) :  2023-12-27 15:14:33.397711
# Label-Test-1
#
# Requests-Proporty-Server-Repsonse-Time-Seconds 0.173161
#
# Test : 7
# Timeout-Paramter-Values :  0.173161
# Request-Status-Code : <bound method Response.raise_for_status of <Response [200]>>
# Server Request Date | Time (UTC) :  2023-12-27 15:14:33.463586
# Label-Test-1
#
# Requests-Proporty-Server-Repsonse-Time-Seconds 0.063747
#
# Test : 8
# Timeout-Paramter-Values :  0.063747
# Request-Status-Code : <bound method Response.raise_for_status of <Response [200]>>
# Server Request Date | Time (UTC) :  2023-12-27 15:14:33.522399
# Label-Test-1
#
# Requests-Proporty-Server-Repsonse-Time-Seconds 0.055885
#
# Test : 9
# Timeout-Paramter-Values :  0.055885
# Request-Status-Code : <bound method Response.raise_for_status of <Response [200]>>
# Server Request Date | Time (UTC) :  2023-12-27 15:14:33.595260
# Label-Test-1
#
# Requests-Proporty-Server-Repsonse-Time-Seconds 0.070413
#
# Test : 10
# Timeout-Paramter-Values :  0.070413
# Request-Status-Code : <bound method Response.raise_for_status of <Response [200]>>
# Server Request Date | Time (UTC) :  2023-12-27 15:14:33.655059
# Label-Test-1
#
# Requests-Proporty-Server-Repsonse-Time-Seconds 0.055886
#
# Test : 11
# Timeout-Paramter-Values :  0.055886
# Request-Status-Code : <bound method Response.raise_for_status of <Response [200]>>
# Server Request Date | Time (UTC) :  2023-12-27 15:14:33.723841
# Label-Test-1
#
# Requests-Proporty-Server-Repsonse-Time-Seconds 0.064491
#
# Test : 12
# Timeout-Paramter-Values :  0.064491
# Request-Status-Code : <bound method Response.raise_for_status of <Response [200]>>
# Server Request Date | Time (UTC) :  2023-12-27 15:14:33.797643
# Label-Test-1
#
# Requests-Proporty-Server-Repsonse-Time-Seconds 0.07064
#
# Test : 13
# Timeout-Paramter-Values :  0.07064
# Request-Status-Code : <bound method Response.raise_for_status of <Response [200]>>
# Server Request Date | Time (UTC) :  2023-12-27 15:14:33.880051
# Label-Test-1
#
# Requests-Proporty-Server-Repsonse-Time-Seconds 0.077561
#
# Test : 14
# Timeout-Paramter-Values :  0.077561
# Request-Status-Code : <bound method Response.raise_for_status of <Response [200]>>
# Server Request Date | Time (UTC) :  2023-12-27 15:14:33.971287
# Label-Test-1
#
# Requests-Proporty-Server-Repsonse-Time-Seconds 0.088665
#
# Test : 15
# Timeout-Paramter-Values :  0.088665
# Request-Status-Code : <bound method Response.raise_for_status of <Response [200]>>
# Server Request Date | Time (UTC) :  2023-12-27 15:14:34.029093
# Label-Test-1
#
# Requests-Proporty-Server-Repsonse-Time-Seconds 0.055166
#
# Test : 16
# Timeout-Paramter-Values :  0.055166
# Request-Status-Code : <bound method Response.raise_for_status of <Response [200]>>
# Server Request Date | Time (UTC) :  2023-12-27 15:14:34.104069
# Label-Test-1
#
# Requests-Proporty-Server-Repsonse-Time-Seconds 0.070677
#
# Test : 17
# Timeout-Paramter-Values :  0.070677
# Request-Status-Code : <bound method Response.raise_for_status of <Response [200]>>
# Server Request Date | Time (UTC) :  2023-12-27 15:14:34.169322
# Label-Test-1
#
# Requests-Proporty-Server-Repsonse-Time-Seconds 0.061708
#
# Test : 18
# Timeout-Paramter-Values :  0.061708
# Request-Status-Code : <bound method Response.raise_for_status of <Response [200]>>
# Server Request Date | Time (UTC) :  2023-12-27 15:14:34.227485
# Label-Test-1
#
# Requests-Proporty-Server-Repsonse-Time-Seconds 0.055152
#
# Test : 19
# Timeout-Paramter-Values :  0.055152
# Request-Status-Code : <bound method Response.raise_for_status of <Response [200]>>
# Server Request Date | Time (UTC) :  2023-12-27 15:14:34.291506
# Label-Test-1
#
# Requests-Proporty-Server-Repsonse-Time-Seconds 0.061002
#
# Test : 20
# Timeout-Paramter-Values :  0.061002
# Request-Status-Code : <bound method Response.raise_for_status of <Response [200]>>
# Server Request Date | Time (UTC) :  2023-12-27 15:14:34.451174
# Label-Test-1
#
# Requests-Proporty-Server-Repsonse-Time-Seconds 0.15693
#
# Test : 21
# Timeout-Paramter-Values :  0.15693
# Request-Status-Code : <bound method Response.raise_for_status of <Response [200]>>
# Server Request Date | Time (UTC) :  2023-12-27 15:14:34.509896
# Label-Test-1
#
# Requests-Proporty-Server-Repsonse-Time-Seconds 0.055383
#
# Test : 22
# Timeout-Paramter-Values :  0.055383
# Request-Status-Code : <bound method Response.raise_for_status of <Response [200]>>
# Server Request Date | Time (UTC) :  2023-12-27 15:14:34.565264
# Label-Test-1
#
# Requests-Proporty-Server-Repsonse-Time-Seconds 0.052272
#
# Test : 23
# Timeout-Paramter-Values :  0.052272
# Request-Status-Code : <bound method Response.raise_for_status of <Response [200]>>
# Server Request Date | Time (UTC) :  2023-12-27 15:14:34.619833
# Label-Test-1
#
# Requests-Proporty-Server-Repsonse-Time-Seconds 0.051992
#
# Test : 24
# Timeout-Paramter-Values :  0.051992
# Request-Status-Code : <bound method Response.raise_for_status of <Response [200]>>
# Server Request Date | Time (UTC) :  2023-12-27 15:14:34.696067
# Label-Test-1
#
# Requests-Proporty-Server-Repsonse-Time-Seconds 0.073252
#
# Test : 25
# Timeout-Paramter-Values :  0.073252
# Request-Status-Code : <bound method Response.raise_for_status of <Response [200]>>
# Server Request Date | Time (UTC) :  2023-12-27 15:14:34.774655
# Label-Test-1
#
# Requests-Proporty-Server-Repsonse-Time-Seconds 0.074289
#
# Test : 26
# Timeout-Paramter-Values :  0.074289
# Request-Status-Code : <bound method Response.raise_for_status of <Response [200]>>
# Server Request Date | Time (UTC) :  2023-12-27 15:14:34.842596
# Label-Test-1
#
# Requests-Proporty-Server-Repsonse-Time-Seconds 0.064662
#
# Test : 27
# Timeout-Paramter-Values :  0.064662
# Request-Status-Code : <bound method Response.raise_for_status of <Response [200]>>
# Server Request Date | Time (UTC) :  2023-12-27 15:14:34.901943
# Label-Test-1
#
# Requests-Proporty-Server-Repsonse-Time-Seconds 0.056777
#
# Test : 28
# Timeout-Paramter-Values :  0.056777
# Request-Status-Code : <bound method Response.raise_for_status of <Response [200]>>
# Server Request Date | Time (UTC) :  2023-12-27 15:14:34.981160
# Label-Test-1
#
# Requests-Proporty-Server-Repsonse-Time-Seconds 0.074955
#
# Test : 29
# Timeout-Paramter-Values :  0.074955
# Request-Status-Code : <bound method Response.raise_for_status of <Response [200]>>
# Server Request Date | Time (UTC) :  2023-12-27 15:14:35.045400
# Label-Test-1
#
# Requests-Proporty-Server-Repsonse-Time-Seconds 0.060737
#
# Test : 30
# Timeout-Paramter-Values :  0.060737
# Request-Status-Code : <bound method Response.raise_for_status of <Response [200]>>
# Server Request Date | Time (UTC) :  2023-12-27 15:14:35.111942
# Label-Test-1
#
# Requests-Proporty-Server-Repsonse-Time-Seconds 0.063416
#
# Test : 31
# Timeout-Paramter-Values :  0.063416
# Request-Status-Code : <bound method Response.raise_for_status of <Response [200]>>
# Server Request Date | Time (UTC) :  2023-12-27 15:14:35.193221
# Label-Test-1
#
# Requests-Proporty-Server-Repsonse-Time-Seconds 0.075722
#
# Test : 32
# Timeout-Paramter-Values :  0.075722
# Request-Status-Code : <bound method Response.raise_for_status of <Response [200]>>
# Server Request Date | Time (UTC) :  2023-12-27 15:14:35.265578
# Label-Test-1
#
# Requests-Proporty-Server-Repsonse-Time-Seconds 0.069411
#
# Test : 33
# Timeout-Paramter-Values :  0.069411
# Request-Status-Code : <bound method Response.raise_for_status of <Response [200]>>
# Server Request Date | Time (UTC) :  2023-12-27 15:14:35.324531
# Label-Test-1
#
# Requests-Proporty-Server-Repsonse-Time-Seconds 0.056812
#
# Test : 34
# Timeout-Paramter-Values :  0.056812
# Request-Status-Code : <bound method Response.raise_for_status of <Response [200]>>
# Server Request Date | Time (UTC) :  2023-12-27 15:14:35.392807
# Label-Test-1
#
# Requests-Proporty-Server-Repsonse-Time-Seconds 0.065833
#
# Test : 35
# Timeout-Paramter-Values :  0.065833
# Request-Status-Code : <bound method Response.raise_for_status of <Response [200]>>
# Server Request Date | Time (UTC) :  2023-12-27 15:14:35.453018
# Label-Test-1
#
# Requests-Proporty-Server-Repsonse-Time-Seconds 0.057005
#
# Test : 36
# Timeout-Paramter-Values :  0.057005
# Request-Status-Code : <bound method Response.raise_for_status of <Response [200]>>
# Server Request Date | Time (UTC) :  2023-12-27 15:14:35.519681
# Label-Test-1
#
# Requests-Proporty-Server-Repsonse-Time-Seconds 0.063694
#
# Test : 37
# Timeout-Paramter-Values :  0.063694
# Request-Status-Code : <bound method Response.raise_for_status of <Response [200]>>
# Server Request Date | Time (UTC) :  2023-12-27 15:14:35.581187
# Label-Test-1
#
# Requests-Proporty-Server-Repsonse-Time-Seconds 0.05937
#
# Test : 38
# Timeout-Paramter-Values :  0.05937
# Request-Status-Code : <bound method Response.raise_for_status of <Response [200]>>
# Server Request Date | Time (UTC) :  2023-12-27 15:14:35.644444
# Label-Test-1
#
# Requests-Proporty-Server-Repsonse-Time-Seconds 0.060967
#
# Test : 39
# Timeout-Paramter-Values :  0.060967
# Request-Status-Code : <bound method Response.raise_for_status of <Response [200]>>
# Server Request Date | Time (UTC) :  2023-12-27 15:14:35.704524
# Label-Test-1
#
# Requests-Proporty-Server-Repsonse-Time-Seconds 0.057455
#
# Test : 40
# Timeout-Paramter-Values :  0.057455
# Request-Status-Code : <bound method Response.raise_for_status of <Response [200]>>
# Server Request Date | Time (UTC) :  2023-12-27 15:14:35.765866
# Label-Test-1
#
# Requests-Proporty-Server-Repsonse-Time-Seconds 0.058757
#
# Test : 41
# Timeout-Paramter-Values :  0.058757
# Request-Status-Code : <bound method Response.raise_for_status of <Response [200]>>
# Server Request Date | Time (UTC) :  2023-12-27 15:14:35.822557
# Label-Test-1
#
# Requests-Proporty-Server-Repsonse-Time-Seconds 0.054347
#
# Test : 42
# Timeout-Paramter-Values :  0.054347
# Request-Status-Code : <bound method Response.raise_for_status of <Response [200]>>
# Server Request Date | Time (UTC) :  2023-12-27 15:14:35.875244
# Label-Test-1
#
# Requests-Proporty-Server-Repsonse-Time-Seconds 0.050305
#
# Test : 43
# Timeout-Paramter-Values :  0.050305
# Request-Status-Code : <bound method Response.raise_for_status of <Response [200]>>
# Server Request Date | Time (UTC) :  2023-12-27 15:14:35.950209
# Label-Test-1
#
# Requests-Proporty-Server-Repsonse-Time-Seconds 0.072679
#
# Test : 44
# Timeout-Paramter-Values :  0.072679
# Request-Status-Code : <bound method Response.raise_for_status of <Response [200]>>
# Server Request Date | Time (UTC) :  2023-12-27 15:14:36.018221
# Label-Test-1
#
# Requests-Proporty-Server-Repsonse-Time-Seconds 0.063472
#
# Test : 45
# Timeout-Paramter-Values :  0.063472
# Request-Status-Code : <bound method Response.raise_for_status of <Response [200]>>
# Server Request Date | Time (UTC) :  2023-12-27 15:14:36.078717
# Label-Test-1
#
# Requests-Proporty-Server-Repsonse-Time-Seconds 0.057212
#
# Test : 46
# Timeout-Paramter-Values :  0.057212
# Request-Status-Code : <bound method Response.raise_for_status of <Response [200]>>
# Server Request Date | Time (UTC) :  2023-12-27 15:14:36.137489
# Label-Test-1
#
# Requests-Proporty-Server-Repsonse-Time-Seconds 0.056216
#
# Test : 47
# Timeout-Paramter-Values :  0.056216
# Request-Status-Code : <bound method Response.raise_for_status of <Response [200]>>
# Server Request Date | Time (UTC) :  2023-12-27 15:14:36.197762
# Label-Test-1
#
# Requests-Proporty-Server-Repsonse-Time-Seconds 0.057314
#
# Test : 48
# Timeout-Paramter-Values :  0.057314
# Request-Status-Code : <bound method Response.raise_for_status of <Response [200]>>
# Server Request Date | Time (UTC) :  2023-12-27 15:14:36.254269
# Label-Test-1
#
# Requests-Proporty-Server-Repsonse-Time-Seconds 0.053067
#
# Test : 49
# Timeout-Paramter-Values :  0.053067
# Request-Status-Code : <bound method Response.raise_for_status of <Response [200]>>
# Server Request Date | Time (UTC) :  2023-12-27 15:14:36.305707
# Label-Test-1
#
# Requests-Proporty-Server-Repsonse-Time-Seconds 0.04936
#
# Test : 50
# Timeout-Paramter-Values :  0.04936
# Request-Status-Code : <bound method Response.raise_for_status of <Response [200]>>
# Server Request Date | Time (UTC) :  2023-12-27 15:14:36.364880
# Label-Test-1
#
# Requests-Proporty-Server-Repsonse-Time-Seconds 0.0564
#
# Test : 51
# Timeout-Paramter-Values :  0.0564
# Request-Status-Code : <bound method Response.raise_for_status of <Response [200]>>
# Server Request Date | Time (UTC) :  2023-12-27 15:14:36.422723
# Label-Test-1
#
# Requests-Proporty-Server-Repsonse-Time-Seconds 0.055671
#
# Test : 52
# Timeout-Paramter-Values :  0.055671
# Request-Status-Code : <bound method Response.raise_for_status of <Response [200]>>
# Server Request Date | Time (UTC) :  2023-12-27 15:14:36.483773
# Label-Test-1
#
# Requests-Proporty-Server-Repsonse-Time-Seconds 0.058254
#
# Test : 53
# Timeout-Paramter-Values :  0.058254
# Request-Status-Code : <bound method Response.raise_for_status of <Response [200]>>
# Server Request Date | Time (UTC) :  2023-12-27 15:14:36.543763
# Label-Test-1
#
# Requests-Proporty-Server-Repsonse-Time-Seconds 0.057451
#
# Test : 54
# Timeout-Paramter-Values :  0.057451
# Request-Status-Code : <bound method Response.raise_for_status of <Response [200]>>
# Server Request Date | Time (UTC) :  2023-12-27 15:14:36.604345
# Label-Test-1
#
# Requests-Proporty-Server-Repsonse-Time-Seconds 0.057977
#
# Test : 55
# Timeout-Paramter-Values :  0.057977
# Request-Status-Code : <bound method Response.raise_for_status of <Response [200]>>
# Server Request Date | Time (UTC) :  2023-12-27 15:14:36.661452
# Label-Test-1
#
# Requests-Proporty-Server-Repsonse-Time-Seconds 0.054601
#
# Test : 56
# Timeout-Paramter-Values :  0.054601
# Request-Status-Code : <bound method Response.raise_for_status of <Response [200]>>
# Server Request Date | Time (UTC) :  2023-12-27 15:14:36.724339
# Label-Test-1
#
# Requests-Proporty-Server-Repsonse-Time-Seconds 0.059201
#
# Test : 57
# Timeout-Paramter-Values :  0.059201
# Request-Status-Code : <bound method Response.raise_for_status of <Response [200]>>
# Server Request Date | Time (UTC) :  2023-12-27 15:14:36.783500
# Label-Test-1
#
# Requests-Proporty-Server-Repsonse-Time-Seconds 0.056979
#
# Test : 58
# Timeout-Paramter-Values :  0.056979
# Request-Status-Code : <bound method Response.raise_for_status of <Response [200]>>
# Server Request Date | Time (UTC) :  2023-12-27 15:14:36.843473
# Label-Test-1
#
# Requests-Proporty-Server-Repsonse-Time-Seconds 0.055993
#
# Test : 59
# Timeout-Paramter-Values :  0.055993
# Request-Status-Code : <bound method Response.raise_for_status of <Response [200]>>
# Server Request Date | Time (UTC) :  2023-12-27 15:14:36.898129
# Label-Test-1
#
# Requests-Proporty-Server-Repsonse-Time-Seconds 0.052119
#
# Test : 60
# Timeout-Paramter-Values :  0.052119
# Request-Status-Code : <bound method Response.raise_for_status of <Response [200]>>
# Server Request Date | Time (UTC) :  2023-12-27 15:14:36.960919
# Label-Test-1
#
# Requests-Proporty-Server-Repsonse-Time-Seconds 0.059938
#
# Test : 61
# Timeout-Paramter-Values :  0.059938
# Request-Status-Code : <bound method Response.raise_for_status of <Response [200]>>
# Server Request Date | Time (UTC) :  2023-12-27 15:14:37.034728
# Label-Test-1
#
# Requests-Proporty-Server-Repsonse-Time-Seconds 0.069527
#
# Test : 62
# Timeout-Paramter-Values :  0.069527
# Request-Status-Code : <bound method Response.raise_for_status of <Response [200]>>
# Server Request Date | Time (UTC) :  2023-12-27 15:14:37.101543
# Label-Test-1
#
# Requests-Proporty-Server-Repsonse-Time-Seconds 0.063935
#
# Test : 63
# Timeout-Paramter-Values :  0.063935
# Request-Status-Code : <bound method Response.raise_for_status of <Response [200]>>
# Server Request Date | Time (UTC) :  2023-12-27 15:14:37.159037
# Label-Test-1
#
# Requests-Proporty-Server-Repsonse-Time-Seconds 0.05419
#
# Test : 64
# Timeout-Paramter-Values :  0.05419
# Request-Status-Code : <bound method Response.raise_for_status of <Response [200]>>
# Server Request Date | Time (UTC) :  2023-12-27 15:14:37.223823
# Label-Test-1
#
# Requests-Proporty-Server-Repsonse-Time-Seconds 0.061888
#
# Test : 65
# Timeout-Paramter-Values :  0.061888
# Request-Status-Code : <bound method Response.raise_for_status of <Response [200]>>
# Server Request Date | Time (UTC) :  2023-12-27 15:14:37.276790
# Label-Test-1
#
# Requests-Proporty-Server-Repsonse-Time-Seconds 0.050413
#
# Test : 66
# Timeout-Paramter-Values :  0.050413
# Request-Status-Code : <bound method Response.raise_for_status of <Response [200]>>
# Server Request Date | Time (UTC) :  2023-12-27 15:14:37.340408
# Label-Test-1
#
# Requests-Proporty-Server-Repsonse-Time-Seconds 0.061069
#
# Test : 67
# Timeout-Paramter-Values :  0.061069
# Request-Status-Code : <bound method Response.raise_for_status of <Response [200]>>
# Server Request Date | Time (UTC) :  2023-12-27 15:14:37.398065
# Label-Test-1
#
# Requests-Proporty-Server-Repsonse-Time-Seconds 0.053822
#
# Test : 68
# Timeout-Paramter-Values :  0.053822
# Request-Status-Code : <bound method Response.raise_for_status of <Response [200]>>
# Server Request Date | Time (UTC) :  2023-12-27 15:14:37.450231
# Label-Test-1
#
# Requests-Proporty-Server-Repsonse-Time-Seconds 0.049819
#
# Test : 69
# Timeout-Paramter-Values :  0.049819
# Request-Status-Code : <bound method Response.raise_for_status of <Response [200]>>
# Server Request Date | Time (UTC) :  2023-12-27 15:14:37.511235
# Label-Test-1
#
# Requests-Proporty-Server-Repsonse-Time-Seconds 0.05868
#
# Test : 70
# Timeout-Paramter-Values :  0.05868
# Request-Status-Code : <bound method Response.raise_for_status of <Response [200]>>
# Server Request Date | Time (UTC) :  2023-12-27 15:14:37.572427
# Label-Test-1
#
# Requests-Proporty-Server-Repsonse-Time-Seconds 0.058616
#
# Test : 71
# Timeout-Paramter-Values :  0.058616
# Request-Status-Code : <bound method Response.raise_for_status of <Response [200]>>
# Server Request Date | Time (UTC) :  2023-12-27 15:14:37.627976
# Label-Test-1
#
# Requests-Proporty-Server-Repsonse-Time-Seconds 0.052929
#
# Test : 72
# Timeout-Paramter-Values :  0.052929
# Request-Status-Code : <bound method Response.raise_for_status of <Response [200]>>
# Server Request Date | Time (UTC) :  2023-12-27 15:14:37.684789
# Label-Test-1
#
# Requests-Proporty-Server-Repsonse-Time-Seconds 0.054163
#
# Test : 73
# Timeout-Paramter-Values :  0.054163
# Request-Status-Code : <bound method Response.raise_for_status of <Response [200]>>
# Server Request Date | Time (UTC) :  2023-12-27 15:14:37.761671
# Label-Test-1
#
# Requests-Proporty-Server-Repsonse-Time-Seconds 0.074309
#
# Test : 74
# Timeout-Paramter-Values :  0.074309
# Request-Status-Code : <bound method Response.raise_for_status of <Response [200]>>
# Server Request Date | Time (UTC) :  2023-12-27 15:14:37.824997
# Label-Test-1
#
# Requests-Proporty-Server-Repsonse-Time-Seconds 0.060789
#
# Test : 75
# Timeout-Paramter-Values :  0.060789
# Request-Status-Code : <bound method Response.raise_for_status of <Response [200]>>
# Server Request Date | Time (UTC) :  2023-12-27 15:14:37.879574
# Label-Test-1
#
# Requests-Proporty-Server-Repsonse-Time-Seconds 0.052032
#
# Test : 76
# Timeout-Paramter-Values :  0.052032
# Request-Status-Code : <bound method Response.raise_for_status of <Response [200]>>
# Server Request Date | Time (UTC) :  2023-12-27 15:14:37.958008
# Label-Test-1
#
# Requests-Proporty-Server-Repsonse-Time-Seconds 0.075646
#
# Test : 77
# Timeout-Paramter-Values :  0.075646
# Request-Status-Code : <bound method Response.raise_for_status of <Response [200]>>
# Server Request Date | Time (UTC) :  2023-12-27 15:14:38.013337
# Label-Test-1
#
# Requests-Proporty-Server-Repsonse-Time-Seconds 0.052604
#
# Test : 78
# Timeout-Paramter-Values :  0.052604
# Request-Status-Code : <bound method Response.raise_for_status of <Response [200]>>
# Server Request Date | Time (UTC) :  2023-12-27 15:14:38.070335
# Label-Test-1
#
# Requests-Proporty-Server-Repsonse-Time-Seconds 0.054903
#
# Test : 79
# Timeout-Paramter-Values :  0.054903
# Request-Status-Code : <bound method Response.raise_for_status of <Response [200]>>
# Server Request Date | Time (UTC) :  2023-12-27 15:14:38.139186
# Label-Test-1
#
# Requests-Proporty-Server-Repsonse-Time-Seconds 0.066077
#
# Test : 80
# Timeout-Paramter-Values :  0.066077
# Request-Status-Code : <bound method Response.raise_for_status of <Response [200]>>
# Server Request Date | Time (UTC) :  2023-12-27 15:14:38.194780
# Label-Test-1
#
# Requests-Proporty-Server-Repsonse-Time-Seconds 0.052343
#
# Test : 81
# Timeout-Paramter-Values :  0.052343
# Request-Status-Code : <bound method Response.raise_for_status of <Response [200]>>
# Server Request Date | Time (UTC) :  2023-12-27 15:14:38.253437
# Label-Test-1
#
# Requests-Proporty-Server-Repsonse-Time-Seconds 0.056052
#
# Test : 82
# Timeout-Paramter-Values :  0.056052
# Request-Status-Code : <bound method Response.raise_for_status of <Response [200]>>
# Server Request Date | Time (UTC) :  2023-12-27 15:14:38.310115
# Label-Test-1
#
# Requests-Proporty-Server-Repsonse-Time-Seconds 0.054895
#
# Test : 83
# Timeout-Paramter-Values :  0.054895
# Request-Status-Code : <bound method Response.raise_for_status of <Response [200]>>
# Server Request Date | Time (UTC) :  2023-12-27 15:14:38.370173
# Label-Test-1
#
# Requests-Proporty-Server-Repsonse-Time-Seconds 0.056781
#
# Test : 84
# Timeout-Paramter-Values :  0.056781
# Request-Status-Code : <bound method Response.raise_for_status of <Response [200]>>
# Server Request Date | Time (UTC) :  2023-12-27 15:14:38.439371
# Label-Test-1
#
# Requests-Proporty-Server-Repsonse-Time-Seconds 0.067053
#
# Test : 85
# Timeout-Paramter-Values :  0.067053
# Request-Status-Code : <bound method Response.raise_for_status of <Response [200]>>
# Server Request Date | Time (UTC) :  2023-12-27 15:14:38.499213
# Label-Test-1
#
# Requests-Proporty-Server-Repsonse-Time-Seconds 0.05735
#
# Test : 86
# Timeout-Paramter-Values :  0.05735
# Request-Status-Code : <bound method Response.raise_for_status of <Response [200]>>
# Server Request Date | Time (UTC) :  2023-12-27 15:14:38.565037
# Label-Test-1
#
# Requests-Proporty-Server-Repsonse-Time-Seconds 0.062397
#
# Test : 87
# Timeout-Paramter-Values :  0.062397
# Request-Status-Code : <bound method Response.raise_for_status of <Response [200]>>
# Server Request Date | Time (UTC) :  2023-12-27 15:14:38.631856
# Label-Test-1
#
# Requests-Proporty-Server-Repsonse-Time-Seconds 0.064597
#
# Test : 88
# Timeout-Paramter-Values :  0.064597
# Request-Status-Code : <bound method Response.raise_for_status of <Response [200]>>
# Server Request Date | Time (UTC) :  2023-12-27 15:14:38.698679
# Label-Test-1
#
# Requests-Proporty-Server-Repsonse-Time-Seconds 0.063686
#
# Test : 89
# Timeout-Paramter-Values :  0.063686
# Request-Status-Code : <bound method Response.raise_for_status of <Response [200]>>
# Server Request Date | Time (UTC) :  2023-12-27 15:14:39.270331
# Label-Test-1
#
# Requests-Proporty-Server-Repsonse-Time-Seconds 0.569478
#
# Test : 90
# Timeout-Paramter-Values :  0.569478
# Request-Status-Code : <bound method Response.raise_for_status of <Response [200]>>
# Server Request Date | Time (UTC) :  2023-12-27 15:14:39.340314
# Label-Test-1
#
# Requests-Proporty-Server-Repsonse-Time-Seconds 0.067264
#
# Test : 91
# Timeout-Paramter-Values :  0.067264
# Request-Status-Code : <bound method Response.raise_for_status of <Response [200]>>
# Server Request Date | Time (UTC) :  2023-12-27 15:14:39.396129
# Label-Test-1
#
# Requests-Proporty-Server-Repsonse-Time-Seconds 0.052346
#
# Test : 92
# Timeout-Paramter-Values :  0.052346
# Request-Status-Code : <bound method Response.raise_for_status of <Response [200]>>
# Server Request Date | Time (UTC) :  2023-12-27 15:14:39.461800
# Label-Test-1
#
# Requests-Proporty-Server-Repsonse-Time-Seconds 0.062604
#
# Test : 93
# Timeout-Paramter-Values :  0.062604
# Request-Status-Code : <bound method Response.raise_for_status of <Response [200]>>
# Server Request Date | Time (UTC) :  2023-12-27 15:14:39.547596
# Label-Test-1
#
# Requests-Proporty-Server-Repsonse-Time-Seconds 0.079027
#
# Test : 94
# Timeout-Paramter-Values :  0.079027
# Request-Status-Code : <bound method Response.raise_for_status of <Response [200]>>
# Server Request Date | Time (UTC) :  2023-12-27 15:14:39.605024
# Label-Test-1
#
# Requests-Proporty-Server-Repsonse-Time-Seconds 0.054948
#
# Test : 95
# Timeout-Paramter-Values :  0.054948
# Request-Status-Code : <bound method Response.raise_for_status of <Response [200]>>
# Server Request Date | Time (UTC) :  2023-12-27 15:14:39.662609
# Label-Test-1
#
# Requests-Proporty-Server-Repsonse-Time-Seconds 0.054816
#
# Test : 96
# Timeout-Paramter-Values :  0.054816
# Request-Status-Code : <bound method Response.raise_for_status of <Response [200]>>
# Server Request Date | Time (UTC) :  2023-12-27 15:14:39.730322
# Label-Test-1
#
# Requests-Proporty-Server-Repsonse-Time-Seconds 0.064614
#
# Test : 97
# Timeout-Paramter-Values :  0.064614
# Request-Status-Code : <bound method Response.raise_for_status of <Response [200]>>
# Server Request Date | Time (UTC) :  2023-12-27 15:14:39.789545
# Label-Test-1
#
# Requests-Proporty-Server-Repsonse-Time-Seconds 0.057187
#
# Test : 98
# Timeout-Paramter-Values :  0.057187
# Request-Status-Code : <bound method Response.raise_for_status of <Response [200]>>
# Server Request Date | Time (UTC) :  2023-12-27 15:14:39.855906
# Label-Test-1
#
# Requests-Proporty-Server-Repsonse-Time-Seconds 0.063275
#
# Test : 99
# Timeout-Paramter-Values :  0.063275
# Request-Status-Code : <bound method Response.raise_for_status of <Response [200]>>
# Server Request Date | Time (UTC) :  2023-12-27 15:14:39.929712
# Label-Test-1
#
# Requests-Proporty-Server-Repsonse-Time-Seconds 0.070103
#
# Test : 100
# Timeout-Paramter-Values :  0.070103
# Request-Status-Code : <bound method Response.raise_for_status of <Response [200]>>
# Server Request Date | Time (UTC) :  2023-12-27 15:14:40.001450
# Label-Test-1
#
# Requests-Proporty-Server-Repsonse-Time-Seconds 0.068144
#
# Test : 101
# Timeout-Paramter-Values :  0.068144
# Request-Status-Code : <bound method Response.raise_for_status of <Response [200]>>
# Server Request Date | Time (UTC) :  2023-12-27 15:14:40.064537
# Label-Test-1
#
# Requests-Proporty-Server-Repsonse-Time-Seconds 0.05859
#
# Test : 102
# Timeout-Paramter-Values :  0.05859
# Request-Status-Code : <bound method Response.raise_for_status of <Response [200]>>
# Server Request Date | Time (UTC) :  2023-12-27 15:14:40.126985
# Label-Test-1
#
# Requests-Proporty-Server-Repsonse-Time-Seconds 0.059906
#
# Test : 103
# Timeout-Paramter-Values :  0.059906
# Request-Status-Code : <bound method Response.raise_for_status of <Response [200]>>
# Server Request Date | Time (UTC) :  2023-12-27 15:14:40.186845
# Label-Test-1
#
# Requests-Proporty-Server-Repsonse-Time-Seconds 0.056836
#
# Test : 104
# Timeout-Paramter-Values :  0.056836
# Request-Status-Code : <bound method Response.raise_for_status of <Response [200]>>
# Server Request Date | Time (UTC) :  2023-12-27 15:14:40.249108
# Label-Test-1
#
# Requests-Proporty-Server-Repsonse-Time-Seconds 0.058103
#
# Test : 105
# Timeout-Paramter-Values :  0.058103
# Request-Status-Code : <bound method Response.raise_for_status of <Response [200]>>
# Server Request Date | Time (UTC) :  2023-12-27 15:14:40.315347
# Label-Test-1
#
# Requests-Proporty-Server-Repsonse-Time-Seconds 0.063633
#
# Test : 106
# Timeout-Paramter-Values :  0.063633
# Request-Status-Code : <bound method Response.raise_for_status of <Response [200]>>
# Server Request Date | Time (UTC) :  2023-12-27 15:14:40.370505
# Label-Test-1
#
# Requests-Proporty-Server-Repsonse-Time-Seconds 0.052352
#
# Test : 107
# Timeout-Paramter-Values :  0.052352
# Request-Status-Code : <bound method Response.raise_for_status of <Response [200]>>
# Server Request Date | Time (UTC) :  2023-12-27 15:14:40.435718
# Label-Test-1
#
# Requests-Proporty-Server-Repsonse-Time-Seconds 0.062375
#
# Test : 108
# Timeout-Paramter-Values :  0.062375
# Request-Status-Code : <bound method Response.raise_for_status of <Response [200]>>
# Server Request Date | Time (UTC) :  2023-12-27 15:14:40.534338
# Label-Test-1
#
# Requests-Proporty-Server-Repsonse-Time-Seconds 0.095427
#
# Test : 109
# Timeout-Paramter-Values :  0.095427
# Request-Status-Code : <bound method Response.raise_for_status of <Response [200]>>
# Server Request Date | Time (UTC) :  2023-12-27 15:14:40.624639
# Label-Test-1
#
# Requests-Proporty-Server-Repsonse-Time-Seconds 0.087683
#
# Test : 110
# Timeout-Paramter-Values :  0.087683
# Request-Status-Code : <bound method Response.raise_for_status of <Response [200]>>
# Server Request Date | Time (UTC) :  2023-12-27 15:14:40.688190
# Label-Test-1
#
# Requests-Proporty-Server-Repsonse-Time-Seconds 0.06094
#
# Test : 111
# Timeout-Paramter-Values :  0.06094
# Request-Status-Code : <bound method Response.raise_for_status of <Response [200]>>
# Server Request Date | Time (UTC) :  2023-12-27 15:14:40.760996
# Label-Test-1
#
# Requests-Proporty-Server-Repsonse-Time-Seconds 0.070007
#
# Test : 112
# Timeout-Paramter-Values :  0.070007
# Request-Status-Code : <bound method Response.raise_for_status of <Response [200]>>
# Server Request Date | Time (UTC) :  2023-12-27 15:14:40.831807
# Label-Test-1
#
# Requests-Proporty-Server-Repsonse-Time-Seconds 0.066588
#
# Test : 113
# Timeout-Paramter-Values :  0.066588
# Request-Status-Code : <bound method Response.raise_for_status of <Response [200]>>
# Server Request Date | Time (UTC) :  2023-12-27 15:14:40.890552
# Label-Test-1
#
# Requests-Proporty-Server-Repsonse-Time-Seconds 0.056144
#
# Test : 114
# Timeout-Paramter-Values :  0.056144
# Request-Status-Code : <bound method Response.raise_for_status of <Response [200]>>
# Server Request Date | Time (UTC) :  2023-12-27 15:14:40.949341
# Label-Test-1
#
# Requests-Proporty-Server-Repsonse-Time-Seconds 0.055546
#
# Test : 115
# Timeout-Paramter-Values :  0.055546
# Request-Status-Code : <bound method Response.raise_for_status of <Response [200]>>
# Server Request Date | Time (UTC) :  2023-12-27 15:14:41.014304
# Label-Test-1
#
# Requests-Proporty-Server-Repsonse-Time-Seconds 0.061244
#
# Test : 116
# Timeout-Paramter-Values :  0.061244
# Request-Status-Code : <bound method Response.raise_for_status of <Response [200]>>
# Server Request Date | Time (UTC) :  2023-12-27 15:14:41.072149
# Label-Test-1
#
# Requests-Proporty-Server-Repsonse-Time-Seconds 0.055187
#
# Test : 117
# Timeout-Paramter-Values :  0.055187
# Request-Status-Code : <bound method Response.raise_for_status of <Response [200]>>
# Server Request Date | Time (UTC) :  2023-12-27 15:14:41.122665
# Label-Test-1
#
# Requests-Proporty-Server-Repsonse-Time-Seconds 0.048031
#
# Test : 118
# Timeout-Paramter-Values :  0.048031
# Request-Status-Code : <bound method Response.raise_for_status of <Response [200]>>
# Server Request Date | Time (UTC) :  2023-12-27 15:14:41.191440
# Label-Test-1
#
# Requests-Proporty-Server-Repsonse-Time-Seconds 0.065544
#
# Test : 119
# Timeout-Paramter-Values :  0.065544
# Request-Status-Code : <bound method Response.raise_for_status of <Response [200]>>
# Server Request Date | Time (UTC) :  2023-12-27 15:14:41.265800
# Label-Test-1
#
# Requests-Proporty-Server-Repsonse-Time-Seconds 0.071328
#
# Test : 120
# Timeout-Paramter-Values :  0.071328
# Request-Status-Code : <bound method Response.raise_for_status of <Response [200]>>
# Server Request Date | Time (UTC) :  2023-12-27 15:14:41.335083
# Label-Test-1
#
# Requests-Proporty-Server-Repsonse-Time-Seconds 0.064184
#
# Test : 121
# Timeout-Paramter-Values :  0.064184
# Request-Status-Code : <bound method Response.raise_for_status of <Response [200]>>
# Server Request Date | Time (UTC) :  2023-12-27 15:14:41.404943
# Label-Test-1
#
# Requests-Proporty-Server-Repsonse-Time-Seconds 0.067346
#
# Test : 122
# Timeout-Paramter-Values :  0.067346
# Request-Status-Code : <bound method Response.raise_for_status of <Response [200]>>
# Server Request Date | Time (UTC) :  2023-12-27 15:14:41.495699
# Label-Test-1
#
# Requests-Proporty-Server-Repsonse-Time-Seconds 0.086385
#
# Test : 123
# Timeout-Paramter-Values :  0.086385
# Request-Status-Code : <bound method Response.raise_for_status of <Response [200]>>
# Server Request Date | Time (UTC) :  2023-12-27 15:14:41.603411
# Label-Test-1
#
# Requests-Proporty-Server-Repsonse-Time-Seconds 0.103693
#
# Test : 124
# Timeout-Paramter-Values :  0.103693
# Request-Status-Code : <bound method Response.raise_for_status of <Response [200]>>
# Server Request Date | Time (UTC) :  2023-12-27 15:14:41.678211
# Label-Test-1
#
# Requests-Proporty-Server-Repsonse-Time-Seconds 0.070431
#
# Test : 125
# Timeout-Paramter-Values :  0.070431
# Request-Status-Code : <bound method Response.raise_for_status of <Response [200]>>
# Server Request Date | Time (UTC) :  2023-12-27 15:14:41.743622
# Label-Test-1
#
# Requests-Proporty-Server-Repsonse-Time-Seconds 0.060889
#
# Test : 126
# Timeout-Paramter-Values :  0.060889
# Request-Status-Code : <bound method Response.raise_for_status of <Response [200]>>
# Server Request Date | Time (UTC) :  2023-12-27 15:14:41.799378
# Label-Test-1
#
# Requests-Proporty-Server-Repsonse-Time-Seconds 0.052427
#
# Test : 127
# Timeout-Paramter-Values :  0.052427
# Request-Status-Code : <bound method Response.raise_for_status of <Response [200]>>
# Server Request Date | Time (UTC) :  2023-12-27 15:14:41.858710
# Label-Test-1
#
# Requests-Proporty-Server-Repsonse-Time-Seconds 0.05681
#
# Test : 128
# Timeout-Paramter-Values :  0.05681
# Request-Status-Code : <bound method Response.raise_for_status of <Response [200]>>
# Server Request Date | Time (UTC) :  2023-12-27 15:14:41.920693
# Label-Test-1
#
# Requests-Proporty-Server-Repsonse-Time-Seconds 0.059298
#
# Test : 129
# Timeout-Paramter-Values :  0.059298
# Request-Status-Code : <bound method Response.raise_for_status of <Response [200]>>
# Server Request Date | Time (UTC) :  2023-12-27 15:14:41.980606
# Label-Test-1
#
# Requests-Proporty-Server-Repsonse-Time-Seconds 0.057074
#
# Test : 130
# Timeout-Paramter-Values :  0.057074
# Request-Status-Code : <bound method Response.raise_for_status of <Response [200]>>
# Server Request Date | Time (UTC) :  2023-12-27 15:14:42.045144
# Label-Test-1
#
# Requests-Proporty-Server-Repsonse-Time-Seconds 0.061178
#
# Test : 131
# Timeout-Paramter-Values :  0.061178
# Request-Status-Code : <bound method Response.raise_for_status of <Response [200]>>
# Server Request Date | Time (UTC) :  2023-12-27 15:14:42.139716
# Label-Test-1
#
# Requests-Proporty-Server-Repsonse-Time-Seconds 0.091333
#
# Test : 132
# Timeout-Paramter-Values :  0.091333
# Request-Status-Code : <bound method Response.raise_for_status of <Response [200]>>
# Server Request Date | Time (UTC) :  2023-12-27 15:14:42.211051
# Label-Test-1
#
# Requests-Proporty-Server-Repsonse-Time-Seconds 0.062239
#
# Test : 133
# Timeout-Paramter-Values :  0.062239
# Request-Status-Code : <bound method Response.raise_for_status of <Response [200]>>
# Server Request Date | Time (UTC) :  2023-12-27 15:14:42.289937
# Label-Test-1
#
# Requests-Proporty-Server-Repsonse-Time-Seconds 0.073792
#
# Test : 134
# Timeout-Paramter-Values :  0.073792
# Request-Status-Code : <bound method Response.raise_for_status of <Response [200]>>
# Server Request Date | Time (UTC) :  2023-12-27 15:14:42.362942
# Label-Test-1
#
# Requests-Proporty-Server-Repsonse-Time-Seconds 0.069918
#
# Test : 135
# Timeout-Paramter-Values :  0.069918
# Request-Status-Code : <bound method Response.raise_for_status of <Response [200]>>
# Server Request Date | Time (UTC) :  2023-12-27 15:14:42.423339
# Label-Test-1
#
# Requests-Proporty-Server-Repsonse-Time-Seconds 0.056418
#
# Test : 136
# Timeout-Paramter-Values :  0.056418
# Request-Status-Code : <bound method Response.raise_for_status of <Response [200]>>
# Server Request Date | Time (UTC) :  2023-12-27 15:14:42.513650
# Label-Test-1
#
# Requests-Proporty-Server-Repsonse-Time-Seconds 0.083503
#
# Test : 137
# Timeout-Paramter-Values :  0.083503
# Request-Status-Code : <bound method Response.raise_for_status of <Response [200]>>
# Server Request Date | Time (UTC) :  2023-12-27 15:14:42.567117
# Label-Test-1
#
# Requests-Proporty-Server-Repsonse-Time-Seconds 0.051258
#
# Test : 138
# Timeout-Paramter-Values :  0.051258
# Request-Status-Code : <bound method Response.raise_for_status of <Response [200]>>
# Server Request Date | Time (UTC) :  2023-12-27 15:14:42.650113
# Label-Test-1
#
# Requests-Proporty-Server-Repsonse-Time-Seconds 0.078438
#
# Test : 139
# Timeout-Paramter-Values :  0.078438
# Request-Status-Code : <bound method Response.raise_for_status of <Response [200]>>
# Server Request Date | Time (UTC) :  2023-12-27 15:14:42.733765
# Label-Test-1
#
# Requests-Proporty-Server-Repsonse-Time-Seconds 0.078914
#
# Test : 140
# Timeout-Paramter-Values :  0.078914
# Request-Status-Code : <bound method Response.raise_for_status of <Response [200]>>
# Server Request Date | Time (UTC) :  2023-12-27 15:14:42.800846
# Label-Test-1
#
# Requests-Proporty-Server-Repsonse-Time-Seconds 0.064367
#
# Test : 141
# Timeout-Paramter-Values :  0.064367
# Request-Status-Code : <bound method Response.raise_for_status of <Response [200]>>
# Server Request Date | Time (UTC) :  2023-12-27 15:14:42.886092
# Label-Test-1
#
# Requests-Proporty-Server-Repsonse-Time-Seconds 0.081253
#
# Test : 142
# Timeout-Paramter-Values :  0.081253
# Request-Status-Code : <bound method Response.raise_for_status of <Response [200]>>
# Server Request Date | Time (UTC) :  2023-12-27 15:14:42.946793
# Label-Test-1
#
# Requests-Proporty-Server-Repsonse-Time-Seconds 0.056982
#
# Test : 143
# Timeout-Paramter-Values :  0.056982
# Request-Status-Code : <bound method Response.raise_for_status of <Response [200]>>
# Server Request Date | Time (UTC) :  2023-12-27 15:14:43.003520
# Label-Test-1
#
# Requests-Proporty-Server-Repsonse-Time-Seconds 0.054273
#
# Test : 144
# Timeout-Paramter-Values :  0.054273
# Request-Status-Code : <bound method Response.raise_for_status of <Response [200]>>
# Server Request Date | Time (UTC) :  2023-12-27 15:14:43.079393
# Label-Test-1
#
# Requests-Proporty-Server-Repsonse-Time-Seconds 0.072352
#
# Test : 145
# Timeout-Paramter-Values :  0.072352
# Request-Status-Code : <bound method Response.raise_for_status of <Response [200]>>
# Server Request Date | Time (UTC) :  2023-12-27 15:14:43.138351
# Label-Test-1
#
# Requests-Proporty-Server-Repsonse-Time-Seconds 0.056841
#
# Test : 146
# Timeout-Paramter-Values :  0.056841
# Request-Status-Code : <bound method Response.raise_for_status of <Response [200]>>
# Server Request Date | Time (UTC) :  2023-12-27 15:14:43.205252
# Label-Test-1
#
# Requests-Proporty-Server-Repsonse-Time-Seconds 0.064414
#
# Test : 147
# Timeout-Paramter-Values :  0.064414
# Request-Status-Code : <bound method Response.raise_for_status of <Response [200]>>
# Server Request Date | Time (UTC) :  2023-12-27 15:14:43.260519
# Label-Test-1
#
# Requests-Proporty-Server-Repsonse-Time-Seconds 0.052847
#
# Test : 148
# Timeout-Paramter-Values :  0.052847
# Request-Status-Code : <bound method Response.raise_for_status of <Response [200]>>
# Server Request Date | Time (UTC) :  2023-12-27 15:14:43.317901
# Label-Test-1
#
# Requests-Proporty-Server-Repsonse-Time-Seconds 0.054617
#
# Test : 149
# Timeout-Paramter-Values :  0.054617
# Request-Status-Code : <bound method Response.raise_for_status of <Response [200]>>
# Server Request Date | Time (UTC) :  2023-12-27 15:14:43.464039
# Label-Test-1
#
# Requests-Proporty-Server-Repsonse-Time-Seconds 0.143012
#
# Test : 150
# Timeout-Paramter-Values :  0.143012
# Request-Status-Code : <bound method Response.raise_for_status of <Response [200]>>
# Server Request Date | Time (UTC) :  2023-12-27 15:14:43.545705
# Label-Test-1
#
# Requests-Proporty-Server-Repsonse-Time-Seconds 0.078607
#
# Test : 151
# Timeout-Paramter-Values :  0.078607
# Request-Status-Code : <bound method Response.raise_for_status of <Response [200]>>
# Server Request Date | Time (UTC) :  2023-12-27 15:14:43.612171
# Label-Test-1
#
# Requests-Proporty-Server-Repsonse-Time-Seconds 0.063313
#
# Test : 152
# Timeout-Paramter-Values :  0.063313
# Request-Status-Code : <bound method Response.raise_for_status of <Response [200]>>
# Server Request Date | Time (UTC) :  2023-12-27 15:14:43.680660
# Label-Test-1
#
# Requests-Proporty-Server-Repsonse-Time-Seconds 0.064677
#
# Test : 153
# Timeout-Paramter-Values :  0.064677
# Request-Status-Code : <bound method Response.raise_for_status of <Response [200]>>
# Server Request Date | Time (UTC) :  2023-12-27 15:14:43.750377
# Label-Test-1
#
# Requests-Proporty-Server-Repsonse-Time-Seconds 0.065727
#
# Test : 154
# Timeout-Paramter-Values :  0.065727
# Request-Status-Code : <bound method Response.raise_for_status of <Response [200]>>
# Server Request Date | Time (UTC) :  2023-12-27 15:14:43.829111
# Label-Test-1
#
# Requests-Proporty-Server-Repsonse-Time-Seconds 0.073644
#
# Test : 155
# Timeout-Paramter-Values :  0.073644
# Request-Status-Code : <bound method Response.raise_for_status of <Response [200]>>
# Server Request Date | Time (UTC) :  2023-12-27 15:14:43.883501
# Label-Test-1
#
# Requests-Proporty-Server-Repsonse-Time-Seconds 0.050514
#
# Test : 156
# Timeout-Paramter-Values :  0.050514
# Request-Status-Code : <bound method Response.raise_for_status of <Response [200]>>
# Server Request Date | Time (UTC) :  2023-12-27 15:14:43.942274
# Label-Test-1
#
# Requests-Proporty-Server-Repsonse-Time-Seconds 0.055412
#
# Test : 157
# Timeout-Paramter-Values :  0.055412
# Request-Status-Code : <bound method Response.raise_for_status of <Response [200]>>
# Server Request Date | Time (UTC) :  2023-12-27 15:14:44.009780
# Label-Test-1
#
# Requests-Proporty-Server-Repsonse-Time-Seconds 0.065208
#
# Test : 158
# Timeout-Paramter-Values :  0.065208
# Request-Status-Code : <bound method Response.raise_for_status of <Response [200]>>
# Server Request Date | Time (UTC) :  2023-12-27 15:14:44.082533
# Label-Test-1
#
# Requests-Proporty-Server-Repsonse-Time-Seconds 0.066473
#
# Test : 159
# Timeout-Paramter-Values :  0.066473
# Request-Status-Code : <bound method Response.raise_for_status of <Response [200]>>
# Server Request Date | Time (UTC) :  2023-12-27 15:14:44.167672
# Label-Test-1
#
# Requests-Proporty-Server-Repsonse-Time-Seconds 0.080643
#
# Test : 160
# Timeout-Paramter-Values :  0.080643
# Request-Status-Code : <bound method Response.raise_for_status of <Response [200]>>
# Server Request Date | Time (UTC) :  2023-12-27 15:14:44.247452
# Label-Test-1
#
# Requests-Proporty-Server-Repsonse-Time-Seconds 0.074521
#
# Test : 161
# Timeout-Paramter-Values :  0.074521
# Request-Status-Code : <bound method Response.raise_for_status of <Response [200]>>
# Server Request Date | Time (UTC) :  2023-12-27 15:14:44.305297
# Label-Test-1
#
# Requests-Proporty-Server-Repsonse-Time-Seconds 0.055614
#
# Test : 162
# Timeout-Paramter-Values :  0.055614
# Request-Status-Code : <bound method Response.raise_for_status of <Response [200]>>
# Server Request Date | Time (UTC) :  2023-12-27 15:14:44.360028
# Label-Test-1
#
# Requests-Proporty-Server-Repsonse-Time-Seconds 0.051942
#
# Test : 163
# Timeout-Paramter-Values :  0.051942
# Request-Status-Code : <bound method Response.raise_for_status of <Response [200]>>
# Server Request Date | Time (UTC) :  2023-12-27 15:14:44.431459
# Label-Test-1
#
# Requests-Proporty-Server-Repsonse-Time-Seconds 0.067994
#
# Test : 164
# Timeout-Paramter-Values :  0.067994
# Request-Status-Code : <bound method Response.raise_for_status of <Response [200]>>
# Server Request Date | Time (UTC) :  2023-12-27 15:14:44.487541
# Label-Test-1
#
# Requests-Proporty-Server-Repsonse-Time-Seconds 0.053687
#
# Test : 165
# Timeout-Paramter-Values :  0.053687
# Request-Status-Code : <bound method Response.raise_for_status of <Response [200]>>
# Server Request Date | Time (UTC) :  2023-12-27 15:14:44.654222
# Label-Test-1
#
# Requests-Proporty-Server-Repsonse-Time-Seconds 0.163558
#
# Test : 166
# Timeout-Paramter-Values :  0.163558
# Request-Status-Code : <bound method Response.raise_for_status of <Response [200]>>
# Server Request Date | Time (UTC) :  2023-12-27 15:14:44.713778
# Label-Test-1
#
# Requests-Proporty-Server-Repsonse-Time-Seconds 0.056642
#
# Test : 167
# Timeout-Paramter-Values :  0.056642
# Request-Status-Code : <bound method Response.raise_for_status of <Response [200]>>
# Server Request Date | Time (UTC) :  2023-12-27 15:14:44.777910
# Label-Test-1
#
# Requests-Proporty-Server-Repsonse-Time-Seconds 0.061711
#
# Test : 168
# Timeout-Paramter-Values :  0.061711
# Request-Status-Code : <bound method Response.raise_for_status of <Response [200]>>
# Server Request Date | Time (UTC) :  2023-12-27 15:14:44.885402
# Label-Test-1
#
# Requests-Proporty-Server-Repsonse-Time-Seconds 0.091459
#
# Test : 169
# Timeout-Paramter-Values :  0.091459
# Request-Status-Code : <bound method Response.raise_for_status of <Response [200]>>
# Server Request Date | Time (UTC) :  2023-12-27 15:14:44.950417
# Label-Test-1
#
# Requests-Proporty-Server-Repsonse-Time-Seconds 0.061139
#
# Test : 170
# Timeout-Paramter-Values :  0.061139
# Request-Status-Code : <bound method Response.raise_for_status of <Response [200]>>
# Server Request Date | Time (UTC) :  2023-12-27 15:14:45.015035
# Label-Test-1
#
# Requests-Proporty-Server-Repsonse-Time-Seconds 0.061543
#
# Test : 171
# Timeout-Paramter-Values :  0.061543
# Request-Status-Code : <bound method Response.raise_for_status of <Response [200]>>
# Server Request Date | Time (UTC) :  2023-12-27 15:14:45.082854
# Label-Test-1
#
# Requests-Proporty-Server-Repsonse-Time-Seconds 0.065745
#
# Test : 172
# Timeout-Paramter-Values :  0.065745
# Request-Status-Code : <bound method Response.raise_for_status of <Response [200]>>
# Server Request Date | Time (UTC) :  2023-12-27 15:14:45.159650
# Label-Test-1
#
# Requests-Proporty-Server-Repsonse-Time-Seconds 0.073729
#
# Test : 173
# Timeout-Paramter-Values :  0.073729
# Request-Status-Code : <bound method Response.raise_for_status of <Response [200]>>
# Server Request Date | Time (UTC) :  2023-12-27 15:14:45.224475
# Label-Test-1
#
# Requests-Proporty-Server-Repsonse-Time-Seconds 0.06183
#
# Test : 174
# Timeout-Paramter-Values :  0.06183
# Request-Status-Code : <bound method Response.raise_for_status of <Response [200]>>
# Server Request Date | Time (UTC) :  2023-12-27 15:14:45.296288
# Label-Test-1
#
# Requests-Proporty-Server-Repsonse-Time-Seconds 0.066689
#
# Test : 175
# Timeout-Paramter-Values :  0.066689
# Request-Status-Code : <bound method Response.raise_for_status of <Response [200]>>
# Server Request Date | Time (UTC) :  2023-12-27 15:14:45.366097
# Label-Test-1
#
# Requests-Proporty-Server-Repsonse-Time-Seconds 0.066647
#
# Test : 176
# Timeout-Paramter-Values :  0.066647
# Request-Status-Code : <bound method Response.raise_for_status of <Response [200]>>
# Server Request Date | Time (UTC) :  2023-12-27 15:14:45.432918
# Label-Test-1
#
# Requests-Proporty-Server-Repsonse-Time-Seconds 0.062899
#
# Test : 177
# Timeout-Paramter-Values :  0.062899
# Request-Status-Code : <bound method Response.raise_for_status of <Response [200]>>
# Server Request Date | Time (UTC) :  2023-12-27 15:14:45.489767
# Label-Test-1
#
# Requests-Proporty-Server-Repsonse-Time-Seconds 0.053887
#
# Test : 178
# Timeout-Paramter-Values :  0.053887
# Request-Status-Code : <bound method Response.raise_for_status of <Response [200]>>
# Server Request Date | Time (UTC) :  2023-12-27 15:14:45.560577
# Label-Test-1
#
# Requests-Proporty-Server-Repsonse-Time-Seconds 0.067935
#
# Test : 179
# Timeout-Paramter-Values :  0.067935
# Request-Status-Code : <bound method Response.raise_for_status of <Response [200]>>
# Server Request Date | Time (UTC) :  2023-12-27 15:14:45.621414
# Label-Test-1
#
# Requests-Proporty-Server-Repsonse-Time-Seconds 0.057971
#
# Test : 180
# Timeout-Paramter-Values :  0.057971
# Request-Status-Code : <bound method Response.raise_for_status of <Response [200]>>
# Server Request Date | Time (UTC) :  2023-12-27 15:14:45.682253
# Label-Test-1
#
# Requests-Proporty-Server-Repsonse-Time-Seconds 0.05663
#
# Test : 181
# Timeout-Paramter-Values :  0.05663
# Request-Status-Code : <bound method Response.raise_for_status of <Response [200]>>
# Server Request Date | Time (UTC) :  2023-12-27 15:14:45.755055
# Label-Test-1
#
# Requests-Proporty-Server-Repsonse-Time-Seconds 0.070293
#
# Test : 182
# Timeout-Paramter-Values :  0.070293
# ...
# Server Request Date | Time (UTC) :  2023-12-27 15:15:32.147908
# Label-Test-3
#
# Requests-Proporty-Server-Repsonse-Time-Seconds 0.052406
#
# Test : 242
# Timeout-Paramter-Values :  0.052406
# Request-Status-Code : <bound method Response.raise_for_status of <Response [200]>>
# Server Request Date | Time (UTC) :  2023-12-27 15:15:32.201764
# Label-Test-3
#
# Requests-Proporty-Server-Repsonse-Time-Seconds 0.050866
#
# Test : 243
# Timeout-Paramter-Values :  0.050866
# Request-Status-Code : <bound method Response.raise_for_status of <Response [200]>>
# Server Request Date | Time (UTC) :  2023-12-27 15:15:32.255520
# Label-Test-3
#
# Requests-Proporty-Server-Repsonse-Time-Seconds 0.05128
#
# Test : 244
# Timeout-Paramter-Values :  0.05128
# Request-Status-Code : <bound method Response.raise_for_status of <Response [200]>>
# Server Request Date | Time (UTC) :  2023-12-27 15:15:32.359239
# Label-Test-3
#
# Requests-Proporty-Server-Repsonse-Time-Seconds 0.100793
#
# Test : 245
# Timeout-Paramter-Values :  0.100793
# Request-Status-Code : <bound method Response.raise_for_status of <Response [200]>>
# Server Request Date | Time (UTC) :  2023-12-27 15:15:32.447991
# Label-Test-3
#
# Requests-Proporty-Server-Repsonse-Time-Seconds 0.079019
#
# Test : 246
# Timeout-Paramter-Values :  0.079019
# Request-Status-Code : <bound method Response.raise_for_status of <Response [200]>>
# Server Request Date | Time (UTC) :  2023-12-27 15:15:32.523878
# Label-Test-3
#
# Requests-Proporty-Server-Repsonse-Time-Seconds 0.073636
#
# Test : 247
# Timeout-Paramter-Values :  0.073636
# Request-Status-Code : <bound method Response.raise_for_status of <Response [200]>>
# Server Request Date | Time (UTC) :  2023-12-27 15:15:32.603664
# Label-Test-3
#
# Requests-Proporty-Server-Repsonse-Time-Seconds 0.074046
#
# Test : 248
# Timeout-Paramter-Values :  0.074046
# Request-Status-Code : <bound method Response.raise_for_status of <Response [200]>>
# Server Request Date | Time (UTC) :  2023-12-27 15:15:32.661735
# Label-Test-3
#
# Requests-Proporty-Server-Repsonse-Time-Seconds 0.056004
#
# Test : 249
# Timeout-Paramter-Values :  0.056004
# Request-Status-Code : <bound method Response.raise_for_status of <Response [200]>>
# Server Request Date | Time (UTC) :  2023-12-27 15:15:32.720717
# Label-Test-3
#
# Requests-Proporty-Server-Repsonse-Time-Seconds 0.056527
#
# Test : 250
# Timeout-Paramter-Values :  0.056527
# Request-Status-Code : <bound method Response.raise_for_status of <Response [200]>>
# Server Request Date | Time (UTC) :  2023-12-27 15:15:32.786220
# Label-Test-3
#
# Requests-Proporty-Server-Repsonse-Time-Seconds 0.063183
#
# Test : 251
# Timeout-Paramter-Values :  0.063183
# Request-Status-Code : <bound method Response.raise_for_status of <Response [200]>>
# Server Request Date | Time (UTC) :  2023-12-27 15:15:32.841636
# Label-Test-3
#
# Requests-Proporty-Server-Repsonse-Time-Seconds 0.052508
#
# Test : 252
# Timeout-Paramter-Values :  0.052508
# Request-Status-Code : <bound method Response.raise_for_status of <Response [200]>>
# Server Request Date | Time (UTC) :  2023-12-27 15:15:32.898337
# Label-Test-3
#
# Requests-Proporty-Server-Repsonse-Time-Seconds 0.054475
#
# Test : 253
# Timeout-Paramter-Values :  0.054475
# Request-Status-Code : <bound method Response.raise_for_status of <Response [200]>>
# Server Request Date | Time (UTC) :  2023-12-27 15:15:32.954452
# Label-Test-3
#
# Requests-Proporty-Server-Repsonse-Time-Seconds 0.053778
#
# Test : 254
# Timeout-Paramter-Values :  0.053778
# Request-Status-Code : <bound method Response.raise_for_status of <Response [200]>>
# Server Request Date | Time (UTC) :  2023-12-27 15:15:33.027369
# Label-Test-3
#
# Requests-Proporty-Server-Repsonse-Time-Seconds 0.068977
#
# Test : 255
# Timeout-Paramter-Values :  0.068977
# Request-Status-Code : <bound method Response.raise_for_status of <Response [200]>>
# Server Request Date | Time (UTC) :  2023-12-27 15:15:33.103596
# Label-Test-3
#
# Requests-Proporty-Server-Repsonse-Time-Seconds 0.071749
#
# Test : 256
# Timeout-Paramter-Values :  0.071749
# Request-Status-Code : <bound method Response.raise_for_status of <Response [200]>>
# Server Request Date | Time (UTC) :  2023-12-27 15:15:33.159414
# Label-Test-3
#
# Requests-Proporty-Server-Repsonse-Time-Seconds 0.05313
#
# Test : 257
# Timeout-Paramter-Values :  0.05313
# Request-Status-Code : <bound method Response.raise_for_status of <Response [200]>>
# Server Request Date | Time (UTC) :  2023-12-27 15:15:33.224275
# Label-Test-3
#
# Requests-Proporty-Server-Repsonse-Time-Seconds 0.06109
#
# Test : 258
# Timeout-Paramter-Values :  0.06109
# Request-Status-Code : <bound method Response.raise_for_status of <Response [200]>>
# Server Request Date | Time (UTC) :  2023-12-27 15:15:33.282086
# Label-Test-3
#
# Requests-Proporty-Server-Repsonse-Time-Seconds 0.054009
#
# Test : 259
# Timeout-Paramter-Values :  0.054009
# Request-Status-Code : <bound method Response.raise_for_status of <Response [200]>>
# Server Request Date | Time (UTC) :  2023-12-27 15:15:33.343922
# Label-Test-3
#
# Requests-Proporty-Server-Repsonse-Time-Seconds 0.058253
#
# Test : 260
# Timeout-Paramter-Values :  0.058253
# Request-Status-Code : <bound method Response.raise_for_status of <Response [200]>>
# Server Request Date | Time (UTC) :  2023-12-27 15:15:33.424952
# Label-Test-3
#
# Requests-Proporty-Server-Repsonse-Time-Seconds 0.077763
#
# Test : 261
# Timeout-Paramter-Values :  0.077763
# Request-Status-Code : <bound method Response.raise_for_status of <Response [200]>>
# Server Request Date | Time (UTC) :  2023-12-27 15:15:33.533663
# Label-Test-3
#
# Requests-Proporty-Server-Repsonse-Time-Seconds 0.106105
#
# Test : 262
# Timeout-Paramter-Values :  0.106105
# Request-Status-Code : <bound method Response.raise_for_status of <Response [200]>>
# Server Request Date | Time (UTC) :  2023-12-27 15:15:33.705202
# Label-Test-3
#
# Requests-Proporty-Server-Repsonse-Time-Seconds 0.168982
#
# Test : 263
# Timeout-Paramter-Values :  0.168982
# Request-Status-Code : <bound method Response.raise_for_status of <Response [200]>>
# Server Request Date | Time (UTC) :  2023-12-27 15:15:33.799030
# Label-Test-3
#
# Requests-Proporty-Server-Repsonse-Time-Seconds 0.090629
#
# Test : 264
# Timeout-Paramter-Values :  0.090629
# Request-Status-Code : <bound method Response.raise_for_status of <Response [200]>>
# Server Request Date | Time (UTC) :  2023-12-27 15:15:33.895386
# Label-Test-3
#
# Requests-Proporty-Server-Repsonse-Time-Seconds 0.091481
#
# Test : 265
# Timeout-Paramter-Values :  0.091481
# Request-Status-Code : <bound method Response.raise_for_status of <Response [200]>>
# Server Request Date | Time (UTC) :  2023-12-27 15:15:33.963414
# Label-Test-3
#
# Requests-Proporty-Server-Repsonse-Time-Seconds 0.063961
#
# Test : 266
# Timeout-Paramter-Values :  0.063961
# Request-Status-Code : <bound method Response.raise_for_status of <Response [200]>>
# Server Request Date | Time (UTC) :  2023-12-27 15:15:34.017233
# Label-Test-3
#
# Requests-Proporty-Server-Repsonse-Time-Seconds 0.050871
#
# Test : 267
# Timeout-Paramter-Values :  0.050871
# Request-Status-Code : <bound method Response.raise_for_status of <Response [200]>>
# Server Request Date | Time (UTC) :  2023-12-27 15:15:34.080098
# Label-Test-3
#
# Requests-Proporty-Server-Repsonse-Time-Seconds 0.059638
#
# Test : 268
# Timeout-Paramter-Values :  0.059638
# Request-Status-Code : <bound method Response.raise_for_status of <Response [200]>>
# Server Request Date | Time (UTC) :  2023-12-27 15:15:34.133922
# Label-Test-3
#
# Requests-Proporty-Server-Repsonse-Time-Seconds 0.050062
#
# Test : 269
# Timeout-Paramter-Values :  0.050062
# Request-Status-Code : <bound method Response.raise_for_status of <Response [200]>>
# Server Request Date | Time (UTC) :  2023-12-27 15:15:34.198748
# Label-Test-3
#
# Requests-Proporty-Server-Repsonse-Time-Seconds 0.062365
#
# Test : 270
# Timeout-Paramter-Values :  0.062365
# Request-Status-Code : <bound method Response.raise_for_status of <Response [200]>>
# Server Request Date | Time (UTC) :  2023-12-27 15:15:34.260584
# Label-Test-3
#
# Requests-Proporty-Server-Repsonse-Time-Seconds 0.05759
#
# Test : 271
# Timeout-Paramter-Values :  0.05759
# Request-Status-Code : <bound method Response.raise_for_status of <Response [200]>>
# Server Request Date | Time (UTC) :  2023-12-27 15:15:34.338357
# Label-Test-3
#
# Requests-Proporty-Server-Repsonse-Time-Seconds 0.073227
#
# Test : 272
# Timeout-Paramter-Values :  0.073227
# Request-Status-Code : <bound method Response.raise_for_status of <Response [200]>>
# Server Request Date | Time (UTC) :  2023-12-27 15:15:34.392214
# Label-Test-3
#
# Requests-Proporty-Server-Repsonse-Time-Seconds 0.050948
#
# Test : 273
# Timeout-Paramter-Values :  0.050948
# Request-Status-Code : <bound method Response.raise_for_status of <Response [200]>>
# Server Request Date | Time (UTC) :  2023-12-27 15:15:34.461027
# Label-Test-3
#
# Requests-Proporty-Server-Repsonse-Time-Seconds 0.06716
#
# Test : 274
# Timeout-Paramter-Values :  0.06716
# Request-Status-Code : <bound method Response.raise_for_status of <Response [200]>>
# Server Request Date | Time (UTC) :  2023-12-27 15:15:34.515486
# Label-Test-3
#
# Requests-Proporty-Server-Repsonse-Time-Seconds 0.050697
#
# Test : 275
# Timeout-Paramter-Values :  0.050697
# Request-Status-Code : <bound method Response.raise_for_status of <Response [200]>>
# Server Request Date | Time (UTC) :  2023-12-27 15:15:34.572371
# Label-Test-3
#
# Requests-Proporty-Server-Repsonse-Time-Seconds 0.053665
#
# Test : 276
# Timeout-Paramter-Values :  0.053665
# Request-Status-Code : <bound method Response.raise_for_status of <Response [200]>>
# Server Request Date | Time (UTC) :  2023-12-27 15:15:34.642150
# Label-Test-3
#
# Requests-Proporty-Server-Repsonse-Time-Seconds 0.066668
#
# Test : 277
# Timeout-Paramter-Values :  0.066668
# Request-Status-Code : <bound method Response.raise_for_status of <Response [200]>>
# Server Request Date | Time (UTC) :  2023-12-27 15:15:34.706977
# Label-Test-3
#
# Requests-Proporty-Server-Repsonse-Time-Seconds 0.062497
#
# Test : 278
# Timeout-Paramter-Values :  0.062497
# Request-Status-Code : <bound method Response.raise_for_status of <Response [200]>>
# Server Request Date | Time (UTC) :  2023-12-27 15:15:34.772798
# Label-Test-3
#
# Requests-Proporty-Server-Repsonse-Time-Seconds 0.06183
#
# Test : 279
# Timeout-Paramter-Values :  0.06183
# Request-Status-Code : <bound method Response.raise_for_status of <Response [200]>>
# Server Request Date | Time (UTC) :  2023-12-27 15:15:34.838623
# Label-Test-3
#
# Requests-Proporty-Server-Repsonse-Time-Seconds 0.062569
#
# Test : 280
# Timeout-Paramter-Values :  0.062569
# Request-Status-Code : <bound method Response.raise_for_status of <Response [200]>>
# Server Request Date | Time (UTC) :  2023-12-27 15:15:34.912426
# Label-Test-3
#
# Requests-Proporty-Server-Repsonse-Time-Seconds 0.070917
#
# Test : 281
# Timeout-Paramter-Values :  0.070917
# Request-Status-Code : <bound method Response.raise_for_status of <Response [200]>>
# Server Request Date | Time (UTC) :  2023-12-27 15:15:34.984500
# Label-Test-3
#
# Requests-Proporty-Server-Repsonse-Time-Seconds 0.068869
#
# Test : 282
# Timeout-Paramter-Values :  0.068869
# Request-Status-Code : <bound method Response.raise_for_status of <Response [200]>>
# Server Request Date | Time (UTC) :  2023-12-27 15:15:35.177984
# Label-Test-3
#
# Requests-Proporty-Server-Repsonse-Time-Seconds 0.190107
#
# Test : 283
# Timeout-Paramter-Values :  0.190107
# Request-Status-Code : <bound method Response.raise_for_status of <Response [200]>>
# Server Request Date | Time (UTC) :  2023-12-27 15:15:35.257770
# Label-Test-3
#
# Requests-Proporty-Server-Repsonse-Time-Seconds 0.076422
#
# Test : 284
# Timeout-Paramter-Values :  0.076422
# Request-Status-Code : <bound method Response.raise_for_status of <Response [200]>>
# Server Request Date | Time (UTC) :  2023-12-27 15:15:35.373461
# Label-Test-3
#
# Requests-Proporty-Server-Repsonse-Time-Seconds 0.110816
#
# Test : 285
# Timeout-Paramter-Values :  0.110816
# Request-Status-Code : <bound method Response.raise_for_status of <Response [200]>>
# Server Request Date | Time (UTC) :  2023-12-27 15:15:35.430309
# Label-Test-3
#
# Requests-Proporty-Server-Repsonse-Time-Seconds 0.05157
#
# Test : 286
# Timeout-Paramter-Values :  0.05157
# Request-Status-Code : <bound method Response.raise_for_status of <Response [200]>>
# Server Request Date | Time (UTC) :  2023-12-27 15:15:35.484164
# Label-Test-3
#
# Requests-Proporty-Server-Repsonse-Time-Seconds 0.052071
#
# Test : 287
# Timeout-Paramter-Values :  0.052071
# Request-Status-Code : <bound method Response.raise_for_status of <Response [200]>>
# Server Request Date | Time (UTC) :  2023-12-27 15:15:35.566944
# Label-Test-3
#
# Requests-Proporty-Server-Repsonse-Time-Seconds 0.078637
#
# Test : 288
# Timeout-Paramter-Values :  0.078637
# Request-Status-Code : <bound method Response.raise_for_status of <Response [200]>>
# Server Request Date | Time (UTC) :  2023-12-27 15:15:35.637588
# Label-Test-3
#
# Requests-Proporty-Server-Repsonse-Time-Seconds 0.06755
#
# Test : 289
# Timeout-Paramter-Values :  0.06755
# Request-Status-Code : <bound method Response.raise_for_status of <Response [200]>>
# Server Request Date | Time (UTC) :  2023-12-27 15:15:35.694403
# Label-Test-3
#
# Requests-Proporty-Server-Repsonse-Time-Seconds 0.053455
#
# Test : 290
# Timeout-Paramter-Values :  0.053455
# Request-Status-Code : <bound method Response.raise_for_status of <Response [200]>>
# Server Request Date | Time (UTC) :  2023-12-27 15:15:35.752283
# Label-Test-3
#
# Requests-Proporty-Server-Repsonse-Time-Seconds 0.05431
#
# Test : 291
# Timeout-Paramter-Values :  0.05431
# Request-Status-Code : <bound method Response.raise_for_status of <Response [200]>>
# Server Request Date | Time (UTC) :  2023-12-27 15:15:35.813086
# Label-Test-3
#
# Requests-Proporty-Server-Repsonse-Time-Seconds 0.056901
#
# Test : 292
# Timeout-Paramter-Values :  0.056901
# Request-Status-Code : <bound method Response.raise_for_status of <Response [200]>>
# Server Request Date | Time (UTC) :  2023-12-27 15:15:35.880517
# Label-Test-3
#
# Requests-Proporty-Server-Repsonse-Time-Seconds 0.064977
#
# Test : 293
# Timeout-Paramter-Values :  0.064977
# Request-Status-Code : <bound method Response.raise_for_status of <Response [200]>>
# Server Request Date | Time (UTC) :  2023-12-27 15:15:35.937364
# Label-Test-3
#
# Requests-Proporty-Server-Repsonse-Time-Seconds 0.054394
#
# Test : 294
# Timeout-Paramter-Values :  0.054394
# Request-Status-Code : <bound method Response.raise_for_status of <Response [200]>>
# Server Request Date | Time (UTC) :  2023-12-27 15:15:36.010850
# Label-Test-3
#
# Requests-Proporty-Server-Repsonse-Time-Seconds 0.069125
#
# Test : 295
# Timeout-Paramter-Values :  0.069125
# Request-Status-Code : <bound method Response.raise_for_status of <Response [200]>>
# Server Request Date | Time (UTC) :  2023-12-27 15:15:36.076256
# Label-Test-3
#
# Requests-Proporty-Server-Repsonse-Time-Seconds 0.062039
#
# Test : 296
# Timeout-Paramter-Values :  0.062039
# Request-Status-Code : <bound method Response.raise_for_status of <Response [200]>>
# Server Request Date | Time (UTC) :  2023-12-27 15:15:36.180976
# Label-Test-3
#
# Requests-Proporty-Server-Repsonse-Time-Seconds 0.10209
#
# Test : 297
# Timeout-Paramter-Values :  0.10209
# Request-Status-Code : <bound method Response.raise_for_status of <Response [200]>>
# Server Request Date | Time (UTC) :  2023-12-27 15:15:36.243811
# Label-Test-3
#
# Requests-Proporty-Server-Repsonse-Time-Seconds 0.058598
#
# Test : 298
# Timeout-Paramter-Values :  0.058598
# Request-Status-Code : <bound method Response.raise_for_status of <Response [200]>>
# Server Request Date | Time (UTC) :  2023-12-27 15:15:36.296790
# Label-Test-3
#
# Requests-Proporty-Server-Repsonse-Time-Seconds 0.050237
#
# Test : 299
# Timeout-Paramter-Values :  0.050237
# Request-Status-Code : <bound method Response.raise_for_status of <Response [200]>>
# Server Request Date | Time (UTC) :  2023-12-27 15:15:36.348529
# Label-Test-3
#
# Requests-Proporty-Server-Repsonse-Time-Seconds 0.049369
#             Request Time UTC  Server Request Response Time Seconds  \
# 0 2023-12-27 15:14:32.948914                              0.162307
# 1 2023-12-27 15:14:33.018725                              0.067600
# 2 2023-12-27 15:14:33.088540                              0.065785
# 3 2023-12-27 15:14:33.149377                              0.057750
# 4 2023-12-27 15:14:33.220187                              0.067119
#
#      Test-Label
# 0  Label-Test-1
# 1  Label-Test-1
# 2  Label-Test-1
# 3  Label-Test-1
# 4  Label-Test-1

# %% [markdown]
# ### Model Evaluation
# - Visualize the data across all three test sets

# %%
# subsetting based on categorical data (Pandas isin method)
t1 = threshold['Test-Label'].isin(['Label-Test-1'])
t1 = threshold[t1]
t2 = threshold['Test-Label'].isin(['Label-Test-2'])
t2 = threshold[t2]
t3 = threshold['Test-Label'].isin(['Label-Test-3'])
t3 = threshold[t3]

# %%
# Generate Line Plots (Subplots)
plt.style.use('ggplot')
fig, ax = plt.subplots(3, figsize = (7,10), sharey= False)
fig.suptitle('Test Set 1 - 3')

#
ax[0].plot(t1.index, t1['Server Request Response Time Seconds'],color = 'b', alpha = 0.3)
ax[1].plot(t2.index, t2['Server Request Response Time Seconds'], color = 'g', alpha = 0.4)
ax[2].plot(t3.index, t3['Server Request Response Time Seconds'], color = 'r', alpha = 0.4)

#Set xlabes
ax[0].set_xlabel('Testing Timeout Parameter Value (0.1, 0.2)')
ax[1].set_xlabel('Testing Timeout Parameter Value (0.4, 0.6)')
ax[2].set_xlabel('Testing Timeout Parameter Value (0.5, 0.8)')

#set y labels
ax[0].set_ylabel('Server-Request-Response-Time-Seconds')
ax[1].set_ylabel('Server-Request-Response-Time-Seconds')
ax[2].set_ylabel('Server-Request-Response-Time-Seconds')

#Set spacing
fig.tight_layout()
plt.show()

# %% [markdown]
# ### CONCLUSION
# - Shortening both the connect and read timeout paramters enable us to test the Timeout exception handling. This confirmed that our models exception handling is working as expected and will raise an errors here.
# - Changing one of the values in the url string apramter means the connection will not work. This has been tested confirming  ConnectionError rasies succesfully.
# - Testing the HTTP error is not currently testable using the endpoint.
#
# - Further testing is required as testing has revelaed out timeout paramter values can be surpassed. This will require further investigation as this is an important feature of our model.
