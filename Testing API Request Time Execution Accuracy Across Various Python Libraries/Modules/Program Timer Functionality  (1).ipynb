# %% [markdown]
# ### Time Module
#
# time.time()
# - We call the time() function, located in the time module, as time.time(). The first time references the module, whereas the second is the function itself. The time() function returns the number of seconds that have passed since the epoch.
# - When we use time.time(), we can see the amount of time that has passed since the epoch.
#
# time.sleep()
# - This function creates a delay in a program that we can use to count/delay time. This function takes a float argument representing the number of seconds that the program will pause for. The program idles for that length of time between outputs.
#
#
# NOTE
#
# In the computing context, an “epoch” references the time according to which a computer calculates its timestamp values. Windows and most UNIX devices set the epoch as January 1, 1970 at 00:00:00.

# %%
import matplotlib.pyplot as plt
import time # import time module

# %% [markdown]
# Below we will use Python's in built list data structure (we dont have to import any packages). In this instance we want to maintain the order of the data that will be generated. This is an  important feature of Python's list data structure.

# %%
times = [] # empty list data stucture

# %% [markdown]
# Program
# - Build a simple program to run
# - Save start time (time.time()) before program execution
# - Execute code/program fucntionality
# - Save end time (time.time() post program execution
# - Add functionality to delay iteration to next loop (time.sleep())
# - Output results

# %%
for test in range(1,100,1):
    print("Test-{}".format(test)) # format() method formats the specified value(s) and insert them inside the string's placeholder.
    start = time.time() # returns the number of seconds that have passed since the epoch
    print("Program-Iteration-{}".format(test)) # execute program
    time.sleep(0.3) # function takes a float argument representing the number of seconds that the program will pause for
    end = time.time()
    time_diff = end - start # calculate time taken to execute program
    print("Program-Execution-Time {}".format(time_diff))
    
    times.append(time_diff)
    time.sleep(1)
# Out:
# Test-1
# Program-Iteration-1
# Program-Execution-Time 0.3001410961151123
# Test-2
# Program-Iteration-2
# Program-Execution-Time 0.3129568099975586
# Test-3
# Program-Iteration-3
# Program-Execution-Time 0.31032729148864746
# Test-4
# Program-Iteration-4
# Program-Execution-Time 0.3129744529724121
# Test-5
# Program-Iteration-5
# Program-Execution-Time 0.31349825859069824
# Test-6
# Program-Iteration-6
# Program-Execution-Time 0.31438469886779785
# Test-7
# Program-Iteration-7
# Program-Execution-Time 0.3151895999908447
# Test-8
# Program-Iteration-8
# Program-Execution-Time 0.3011777400970459
# Test-9
# Program-Iteration-9
# Program-Execution-Time 0.3107161521911621
# Test-10
# Program-Iteration-10
# Program-Execution-Time 0.3100144863128662
# Test-11
# Program-Iteration-11
# Program-Execution-Time 0.3118782043457031
# Test-12
# Program-Iteration-12
# Program-Execution-Time 0.315044641494751
# Test-13
# Program-Iteration-13
# Program-Execution-Time 0.3123140335083008
# Test-14
# Program-Iteration-14
# Program-Execution-Time 0.31251025199890137
# Test-15
# Program-Iteration-15
# Program-Execution-Time 0.31402158737182617
# Test-16
# Program-Iteration-16
# Program-Execution-Time 0.31229734420776367
# Test-17
# Program-Iteration-17
# Program-Execution-Time 0.32094788551330566
# Test-18
# Program-Iteration-18
# Program-Execution-Time 0.31241846084594727
# Test-19
# Program-Iteration-19
# Program-Execution-Time 0.31531763076782227
# Test-20
# Program-Iteration-20
# Program-Execution-Time 0.3146967887878418
# Test-21
# Program-Iteration-21
# Program-Execution-Time 0.3128776550292969
# Test-22
# Program-Iteration-22
# Program-Execution-Time 0.300595760345459
# Test-23
# Program-Iteration-23
# Program-Execution-Time 0.3116159439086914
# Test-24
# Program-Iteration-24
# Program-Execution-Time 0.30004096031188965
# Test-25
# Program-Iteration-25
# Program-Execution-Time 0.3109297752380371
# Test-26
# Program-Iteration-26
# Program-Execution-Time 0.31104063987731934
# Test-27
# Program-Iteration-27
# Program-Execution-Time 0.3116583824157715
# Test-28
# Program-Iteration-28
# Program-Execution-Time 0.31331539154052734
# Test-29
# Program-Iteration-29
# Program-Execution-Time 0.457538366317749
# Test-30
# Program-Iteration-30
# Program-Execution-Time 0.31274867057800293
# Test-31
# Program-Iteration-31
# Program-Execution-Time 0.3098304271697998
# Test-32
# Program-Iteration-32
# Program-Execution-Time 0.30123353004455566
# Test-33
# Program-Iteration-33
# Program-Execution-Time 0.30002331733703613
# Test-34
# Program-Iteration-34
# Program-Execution-Time 0.31083178520202637
# Test-35
# Program-Iteration-35
# Program-Execution-Time 0.31088829040527344
# Test-36
# Program-Iteration-36
# Program-Execution-Time 0.31113719940185547
# Test-37
# Program-Iteration-37
# Program-Execution-Time 0.30992865562438965
# Test-38
# Program-Iteration-38
# Program-Execution-Time 0.31008481979370117
# Test-39
# Program-Iteration-39
# Program-Execution-Time 0.3112461566925049
# Test-40
# Program-Iteration-40
# Program-Execution-Time 0.3175697326660156
# Test-41
# Program-Iteration-41
# Program-Execution-Time 0.31400609016418457
# Test-42
# Program-Iteration-42
# Program-Execution-Time 0.31186580657958984
# Test-43
# Program-Iteration-43
# Program-Execution-Time 0.30817675590515137
# Test-44
# Program-Iteration-44
# Program-Execution-Time 0.314159631729126
# Test-45
# Program-Iteration-45
# Program-Execution-Time 0.3129117488861084
# Test-46
# Program-Iteration-46
# Program-Execution-Time 0.31420278549194336
# Test-47
# Program-Iteration-47
# Program-Execution-Time 0.31157445907592773
# Test-48
# Program-Iteration-48
# Program-Execution-Time 0.31493330001831055
# Test-49
# Program-Iteration-49
# Program-Execution-Time 0.3117218017578125
# Test-50
# Program-Iteration-50
# Program-Execution-Time 0.31231188774108887
# Test-51
# Program-Iteration-51
# Program-Execution-Time 0.3134915828704834
# Test-52
# Program-Iteration-52
# Program-Execution-Time 0.31238436698913574
# Test-53
# Program-Iteration-53
# Program-Execution-Time 0.31274986267089844
# Test-54
# Program-Iteration-54
# Program-Execution-Time 0.3146824836730957
# Test-55
# Program-Iteration-55
# Program-Execution-Time 0.30004429817199707
# Test-56
# Program-Iteration-56
# Program-Execution-Time 0.3155646324157715
# Test-57
# Program-Iteration-57
# Program-Execution-Time 0.31520819664001465
# Test-58
# Program-Iteration-58
# Program-Execution-Time 0.31182026863098145
# Test-59
# Program-Iteration-59
# Program-Execution-Time 0.3098728656768799
# Test-60
# Program-Iteration-60
# Program-Execution-Time 0.31268978118896484
# Test-61
# Program-Iteration-61
# Program-Execution-Time 0.31458282470703125
# Test-62
# Program-Iteration-62
# Program-Execution-Time 0.3103315830230713
# Test-63
# Program-Iteration-63
# Program-Execution-Time 0.3002786636352539
# Test-64
# Program-Iteration-64
# Program-Execution-Time 0.3128972053527832
# Test-65
# Program-Iteration-65
# Program-Execution-Time 0.31100988388061523
# Test-66
# Program-Iteration-66
# Program-Execution-Time 0.3152766227722168
# Test-67
# Program-Iteration-67
# Program-Execution-Time 0.31374454498291016
# Test-68
# Program-Iteration-68
# Program-Execution-Time 0.32298731803894043
# Test-69
# Program-Iteration-69
# Program-Execution-Time 0.313521146774292
# Test-70
# Program-Iteration-70
# Program-Execution-Time 0.31287217140197754
# Test-71
# Program-Iteration-71
# Program-Execution-Time 0.31412649154663086
# Test-72
# Program-Iteration-72
# Program-Execution-Time 0.3142967224121094
# Test-73
# Program-Iteration-73
# Program-Execution-Time 0.30942821502685547
# Test-74
# Program-Iteration-74
# Program-Execution-Time 0.31304168701171875
# Test-75
# Program-Iteration-75
# Program-Execution-Time 0.31269121170043945
# Test-76
# Program-Iteration-76
# Program-Execution-Time 0.3110196590423584
# Test-77
# Program-Iteration-77
# Program-Execution-Time 0.31122756004333496
# Test-78
# Program-Iteration-78
# Program-Execution-Time 0.3002500534057617
# Test-79
# Program-Iteration-79
# Program-Execution-Time 0.30089902877807617
# Test-80
# Program-Iteration-80
# Program-Execution-Time 0.31496453285217285
# Test-81
# Program-Iteration-81
# Program-Execution-Time 0.3011443614959717
# Test-82
# Program-Iteration-82
# Program-Execution-Time 0.30919933319091797
# Test-83
# Program-Iteration-83
# Program-Execution-Time 0.3089885711669922
# Test-84
# Program-Iteration-84
# Program-Execution-Time 0.3122248649597168
# Test-85
# Program-Iteration-85
# Program-Execution-Time 0.3140871524810791
# Test-86
# Program-Iteration-86
# Program-Execution-Time 0.31319689750671387
# Test-87
# Program-Iteration-87
# Program-Execution-Time 0.3114008903503418
# Test-88
# Program-Iteration-88
# Program-Execution-Time 0.3097505569458008
# Test-89
# Program-Iteration-89
# Program-Execution-Time 0.30312418937683105
# Test-90
# Program-Iteration-90
# Program-Execution-Time 0.3148019313812256
# Test-91
# Program-Iteration-91
# Program-Execution-Time 0.31440281867980957
# Test-92
# Program-Iteration-92
# Program-Execution-Time 0.3018920421600342
# Test-93
# Program-Iteration-93
# Program-Execution-Time 0.3010406494140625
# Test-94
# Program-Iteration-94
# Program-Execution-Time 0.311068058013916
# Test-95
# Program-Iteration-95
# Program-Execution-Time 0.3103034496307373
# Test-96
# Program-Iteration-96
# Program-Execution-Time 0.3098599910736084
# Test-97
# Program-Iteration-97
# Program-Execution-Time 0.3110158443450928
# Test-98
# Program-Iteration-98
# Program-Execution-Time 0.30135464668273926
# Test-99
# Program-Iteration-99
# Program-Execution-Time 0.3100583553314209

# %% [markdown]
# Check some recorded details.

# %%
print(min(times))
print(max(times))
# Out:
# 0.30002331733703613
# 0.457538366317749

# %% [markdown]
# Generate a simple Line Plot to visualise our list data using Matplolib package.

# %%
plt.style.use('ggplot')
plt.plot(times,color = 'r', alpha = 0.3)
plt.show()
